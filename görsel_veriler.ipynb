# %%
from PIL import Image
import PIL

# %%
img=Image.open('./thumb.jpeg')

# %%
img.show()

# %%
img.size
# Out:
# (1500, 500)

# %%
img.mode
# Out:
# 'RGB'

# %%
img.rotate(90,expand=1).size
# Out:
# (500, 1500)

# %%
img.transpose(method=Image.FLIP_TOP_BOTTOM)
# Out:
# <PIL.Image.Image image mode=RGB size=1500x500>

# %% [markdown]
# Fotoğrafı estetik açıdan bozmadan büyütüp küçültme

# %%
img.resize((500,500))
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
width,height=img.size
new_width=int(width/5)
new_height=int(height/5)

small_image=img.resize((new_width,new_height))

# %%
small_image.show()

# %%
small_image.save('./small_image.jpg')
